# %%
import matplotlib.pyplot as plt
# %matplotlib inline #shows the chart without having to type plt.show

# %%
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
x = list(range(150))
x [0:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
plt .plot(x)
plt.show() #cleans above up

# %%
plt.plot(range(len(x)), y = x)
plt.show()

# %%
plt.plot(x)
plt.xlim(-20, 200)
plt.ylim(-5, 160)
plt.show()

# %%
plt.plot(x, c='red') #list, then color
plt.show()

# %%
from random import randint

# %%
# some random data
x1 = [randint(-5, 25) + n for n in range(150)]
x2 = [x + randint(-6, 6) for x in x1] # for each item in x1 one, we are going to add a number between -6 and 6 to it

# %%
plt.plot(x1, c='green', alpha=0.5)
plt.plot(x2, c='red', alpha=0.5)
plt.xlim(-20, 200)
plt.ylim(-5, 160)
plt.show()

# %%
plt.scatter(range(len(x1)), y = x1)
plt.scatter(range(len(x2)), y = x2)
plt.show()

# %%
plt.scatter(range(len(x1)), x1, s=30, c='red')
plt.scatter(range(len(x1)), x1, s=10, c='red')
plt.show()

# %%
plt.scatter(range(len(x1)), x1, s=30, c='pink')
plt.scatter(range(len(x1)), x1, s=10, c='purple')
plt.title('Random Generator')
plt.xlim(-20, 200)
plt.ylim(-5, 160)
plt.show()

# %%
x = list(range(-49, 50))
y = [n**2 for n in x]
plt.scatter (x, y)
plt.title('An Exponential Distribution, $y = x^2$')
plt.xlabel('x')
plt.ylabel('x^2')
plt.show()

# %%
x = [1, 2, 3.14, 4]
y = [n ** 2 for n in x]
plt.scatter(x, y)
plt.xticks([1, 2, 3.14, 4], ['one', 'two', '$\pi$', 'four']) # create tick mark names
plt.show()

# %%
import math # imported math for the sin

x = range(-4, 4)
y = [math.sin(n) for n in x] 
plt.scatter(x, y) # creating a scatter plot
plt.plot(x, y, ls=':') # : means dotted line. -- is dashed. This is creating a line plot with the scatter plot
plt.title('An approximation of the sin function')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.show()

# %%
x = range(1, 5)
y = x
plt.scatter(x, y)
plt.yticks([1, 2, 3, 4], ['one', 'two', 'three', 'four'], rotation=45)
plt.xticks(rotation=45) # rotation of xticks labels
plt.show()

# %%
import random

weekdays = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'] * 2

x = range(14)
y = [random.randint(1, 10) for _ in x]
plt.plot(x, y)
plt.xticks(x, weekdays, rotation=60) # list, labels, rotation
plt.show()

# %%
x = list(range(-4, 4))
x.append(3.14159)
y = [math.sin(n) for n in x]

plt.scatter(x, y)
plt.plot(x, y, ls=':') #list, list, type of line-dotted

plt.text(0.25, 0, '(0, 0)', fontsize=10, color='blue') # added text to 0,0
plt.text(1.2, 0.1, '($\pi$, sin($\pi$))', fontsize=14, color='firebrick') # text to sin of pi

plt.show()

# %%
x = range(-3, 10)
y = [n * 2 for n in x]
z = [n / 2 for n in x]

plt.plot(x, y, c='orange')
plt.plot(x, z, c='green')

plt.annotate('Intersection', xy=(0, 0), xytext=(-3, 5), #xy is the intersection of these two lines. -3, 5 is the place of the text"intersection"
             arrowprops={'facecolor': 'blue'})

plt.show()

# %%
x = range(-4, 5)
sin_x = [math.sin(n) for n in x]
cos_x = [math.cos(n) for n in x]

plt.figure(figsize=(14, 6)) # (width, height)

plt.scatter(x, sin_x, c='blue')
plt.scatter(x, cos_x, c='orange')
plt.plot(x, sin_x, c='blue', label='$\sin(x)$')
plt.plot(x, cos_x, c='orange', label='$\cos(x)$')

plt.legend(loc='upper right') # the position of the legend
plt.title('Approximate sin and cosine curves')
plt.xlabel('$x$') # $ makes the fancy x

plt.show()

# %%
x = range(1, 10)
y = [3 * n + 5 for n in x]
plt.plot(x, y)
plt.savefig('my-figure') #saves this figure to computer
plt.show()

# %%
n_rows = 1
n_cols = 2

# some data to play with
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]
z = [1, 2, 3, 4, 5]

# plot the first subplot
plt.subplot(n_rows, n_cols, 1) #last number is the first item
plt.plot(x, y)
plt.title('x ~ y')

# the second subplot
plt.subplot(n_rows, n_cols, 2)
plt.plot(x, z)
plt.title('x ~ z')

plt.show()

# %%
# some data to play with
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]
z = [1, 2, 3, 4, 5]

# plot the first subplot
plt.subplot(121) # 1(rows)x 2(columns) x plot number (aka first item to appear)
plt.plot(x, y)
plt.title('x ~ y')

# the second subplot
plt.subplot(122)
plt.plot(x, z)
plt.title('x ~ z')

plt.show()

# %%
x = [1, 1, 2, 3, 3, 3, 4, 4, 5]

plt.hist(x)
plt.show()

# %%
x = [1, 1, 2, 3, 3, 3, 4, 4, 5]

plt.hist(x, bins=[0, 1, 2, 3, 4, 5, 6])
plt.show()

# %%
x = [1, 1, 2, 3, 3, 3, 4, 4, 5]

plt.figure(figsize=(16, 6))
plt.suptitle(f'x = {x}') #super title. Title of all of the subplots

plt.subplot(131)
plt.hist(x, bins=[0, 1, 2, 3, 4, 5, 6]) # you can also create a a list of the bins called 'bins' and do instead bins=bins
plt.title('align="middle" (default)')

plt.subplot(132)
plt.hist(x, bins=[0, 1, 2, 3, 4, 5, 6], align='left')
plt.title('align="left"')

plt.subplot(133)
plt.hist(x, bins=[0, 1, 2, 3, 4, 5, 6], align='right')
plt.title('align="right"')

plt.show()

# %%
x1 = [randint(1, 5) for _ in range(20)]
x2 = [randint(1, 5) for _ in range(20)]

plt.hist(x1, bins=[0, 1, 2, 3, 4, 5, 6], align='left', edgecolor='black', alpha=0.5, color='blue')
plt.hist(x2, bins=[0, 1, 2, 3, 4, 5, 6], align='left', edgecolor='black', alpha=0.5, color='yellow')

plt.show()

# %%
x1 = [randint(1, 5) for _ in range(20)]
x2 = [randint(1, 5) for _ in range(20)]

plt.hist(x1, bins=[1, 2, 3, 4, 5, 6], align='left', edgecolor='black', alpha=0.4, label='$x_1$')# adds label
plt.hist(x2, bins=[1, 2, 3, 4, 5, 6], align='left', edgecolor='black', alpha=0.4, label='$x_2$')
plt.legend()

plt.show()

# %%
x1 = [randint(1, 5) for _ in range(20)]
x2 = [randint(1, 5) for _ in range(20)]

plt.hist((x1, x2), bins=[1, 2, 3, 4, 5, 6], align='left', edgecolor='black', alpha=0.6, label=['$x_1$', '$x_2$'])

plt.legend() # adds legend
plt.show()

# %%
plt.figure(figsize=(12, 8)) # size of our figure
for i in range(1, 5): # do a for loop to generate the data, get a total and plot the subplots
    n = 10 ** i #10 to the i power
    x1 = [randint(1, 6) for _ in range(n)]
    x2 = [randint(1, 6) for _ in range(n)]

    total = [x + y for x, y in zip(x1, x2)] # zip merges them together into coordinate like

    plt.subplot(2, 2, i) # 2x2 matrix of charts
    plt.hist(total, bins=range(2, 14), align='left', color='white', edgecolor='black')
    plt.title(f'n = {n}')

plt.suptitle('Sum of 2 dice rolls')
plt.show()

# %%
n = 1000
x1 = [randint(1, 6) for _ in range(n)]
x2 = [randint(1, 6) for _ in range(n)]

plt.hist2d(x=x1, y=x2, bins=range(1, 8))
plt.xlabel('x1')
plt.ylabel('x2')
plt.colorbar() #plots the gradient on the right
plt.show()

# %%
x = [n / 100 for n in range(-10000, 10000)]
y = list(x)

plt.plot(x, y)
plt.xscale('linear') # the default
plt.yscale('log') # plot this as a log scale. log scale puts it 10^-2, etc. It brings in the outliers into the graph better
plt.show()
